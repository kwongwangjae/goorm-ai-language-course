# %% [markdown]
# ![image.png](attachment:f4220d63-60a8-4d5f-8175-0d9f3736eccd.png)

# %%
import tensorflow as tf

# x, y의 데이터 값
data = [[2,81], [4,93], [6, 91], [8, 97]]
x_train = [x_row[0] for x_row in data]
y_train = [y_row[1] for y_row in data]
w = tf.Variable(tf.random.uniform([1], 0, 10, dtype=tf.float64, seed=0))
b = tf.Variable(tf.random.uniform([1], 0, 100, dtype=tf.float64, seed=0))

# 기울기와 절편을 통해 계산되는 예상 Y 값
def hypothesis(w,b): # 가설
    return x_train * w + b
    
def cost(w,b): # 손실을 계산하는 함수
    return tf.sqrt(tf.reduce_mean(tf.square(hypothesis(w,b) - y_train )))

# 확률적 경사하강법
opt = tf.keras.optimizers.SGD(learning_rate=0.1)
for i in range(2000): #steps
    # 자동 미분을 위한 테이프
    with tf.GradientTape() as tape:
        loss = cost(w,b) # 기록할 내용이 w, b임을 명시
    gradients = tape.gradient(loss, [w, b]) # 손실에 대한 w, b의 미분값 계산
    opt.apply_gradients(zip(gradients, [w,b])) # 미분값으로 w와 b를 업데이트(조정)
    if i % 100 == 0:
        print(i, f'{loss.numpy()}, {w.numpy()}, {b.numpy()}')
# Out:
# 0 26.279364009259414, [2.35816371], [55.23229736]
# 100 8.469754359381584, [5.56275245], [59.52928875]
# 200 7.0731953535968275, [4.94529357], [63.21401926]
# 300 5.781697082243932, [4.35166005], [66.75657028]
# 400 4.66247891881602, [3.79938018], [70.05234034]
# 500 3.8077423615916004, [3.31753658], [72.92777687]
# 600 3.2798377325370676, [2.94021501], [75.1794706]
# 700 3.028415963474706, [2.68106506], [76.72596671]
# 800 2.9311656822474226, [2.52045965], [77.68439107]
# 900 2.8974956764715767, [2.42611529], [78.24739788]
# 1000 2.886347664736859, [2.37186214], [78.57115749]
# 1100 2.882714024004019, [2.34089463], [78.75595835]
# 1200 2.8815358168982663, [2.32326203], [78.86118213]
# 1300 2.8811544333443457, [2.31323029], [78.92104732]
# 1400 2.881031048322172, [2.30752439], [78.95509766]
# 1500 2.880991137995996, [2.30427925], [78.97446329]
# 1600 2.8809782292816943, [2.30243367], [78.98547692]
# 1700 2.8809740541269684, [2.30138406], [78.99174054]
# 1800 2.880972703735982, [2.30078713], [78.99530274]
# 1900 2.8809722669731808, [2.30044765], [78.99732861]

# %% [markdown]
# ![image.png](attachment:58051bec-87ea-4a1e-9a98-bbd54432fed1.png)

# %%
import tensorflow as tf
import numpy as np

# x, y의 데이터 값
x_data = np.array([0.3, -0.78, 1.26, 0.03, 1.11, 15.17, 0.24, -0.24, -0.47, -0.77,
                   -0.37, -0.85, -0.41, -0.27, 0.02, -0.76, 2.66], dtype=np.float64)
y_data = np.array([12.27, 14.44, 11.87, 18.75, 17.52, 9.29, 16.37, 19.78, 19.51, 
                   12.65,14.74, 10.72, 21.94, 12.83, 15.51, 17.14, 14.42], dtype=np.float64)

w = tf.Variable(tf.random.uniform([1], 0, 10, dtype=tf.float64, seed=0))
b = tf.Variable(tf.random.uniform([1], 0, 100, dtype=tf.float64, seed=0))

# 기울기와 절편을 통해 계산되는 예상 Y 값
def hypothesis(w,b): # 가설
    return x_data * w + b
    
def cost(w,b): # 손실을 계산하는 함수
    return tf.sqrt(tf.reduce_mean(tf.square(hypothesis(w,b) - y_data )))

# 확률적 경사하강법
opt = tf.keras.optimizers.SGD(learning_rate=0.1)
for i in range(2000): #steps
    # 자동 미분을 위한 테이프
    with tf.GradientTape() as tape:
        loss = cost(w,b) # 기록할 내용이 w, b임을 명시
    gradients = tape.gradient(loss, [w, b]) # 손실에 대한 w, b의 미분값 계산
    opt.apply_gradients(zip(gradients, [w,b])) # 미분값으로 w와 b를 업데이트(조정)
    if i % 100 == 0:
        print(i, f'{loss.numpy()}, {w.numpy()}, {b.numpy()}')
# Out:
# 0 66.7574644987437, [0.6159874], [81.05142089]
# 100 53.98684222340858, [-3.81352896], [71.18514932]
# 200 44.64325373974105, [-3.59245593], [61.52788734]
# 300 35.34903836418035, [-2.94511182], [51.90912073]
# 400 26.093644911326617, [-2.27607172], [42.31214572]
# 500 16.939623577266936, [-1.61014102], [32.76840128]
# 600 8.215323721613911, [-0.96032739], [23.45570522]
# 700 3.1946318561319433, [-0.48675508], [16.66878244]
# 800 3.034889253730613, [-0.42010455], [15.71359151]
# 900 3.034557319636418, [-0.41710689], [15.67063108]
# 1000 3.0345566840651386, [-0.41697572], [15.66875128]
# 1100 3.0345566828483834, [-0.41696998], [15.66866903]
# 1200 3.0345566828460546, [-0.41696973], [15.66866543]
# 1300 3.0345566828460493, [-0.41696972], [15.66866527]
# 1400 3.0345566828460497, [-0.41696972], [15.66866526]
# 1500 3.0345566828460493, [-0.41696972], [15.66866526]
# 1600 3.0345566828460493, [-0.41696972], [15.66866526]
# 1700 3.0345566828460493, [-0.41696972], [15.66866526]
# 1800 3.0345566828460493, [-0.41696972], [15.66866526]
# 1900 3.0345566828460493, [-0.41696972], [15.66866526]

# %% [markdown]
# ![image.png](attachment:89c1fb60-d456-4cd1-b558-41568527503a.png)

# %% [markdown]
# ![image.png](attachment:3d826e1e-d980-47d1-8bfc-664c27a668e5.png)

# %% [markdown]
# ![image.png](attachment:f11bcc50-a021-43e2-ad05-b0b47d904dec.png)

# %% [markdown]
# ![image.png](attachment:d26e67c3-2760-4ecc-97df-b28465f7f992.png)

# %% [markdown]
# ![image.png](attachment:f70441b9-c8e8-4d91-829d-fbffa347d2ff.png)

# %% [markdown]
# ![image.png](attachment:19cede09-3ffa-49f6-9ca9-fb85f39e0253.png)
