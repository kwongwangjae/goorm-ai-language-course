# %%
print(1+1)
print("apple")
print('apple, banana')
print("값은 :", 20)
print("10",10)
# Out:
# 2
# apple
# apple, banana
# 값은 : 20
# 10 10

# %%
print(5 * 7 / 2)
# Out:
# 17.5

# %%
print(60 * 2 + 25 * 1)
# Out:
# 145

# %%
print("333" + "777")
print(333 + 777)
# Out:
# 333777
# 1110

# %%
# print 함수 사용법
print(7 + 5)
print(7 - 5)
print(7 * 5)
print(7 / 5)
print("7 + 5 = ", 7 + 5)
print("7 - 5 = ", 7 - 5)
print("7 * 5 = ", 7 * 5)
print("7 / 5 = ", 7 / 5)
'''
document String
print("주석")
주석을 꼼꼼하게 써야한다.
'''
# Out:
# 12
# 2
# 35
# 1.4
# 7 + 5 =  12
# 7 - 5 =  2
# 7 * 5 =  35
# 7 / 5 =  1.4
# '\ndocument String\nprint("주석")\n'

# %%
#파이썬 숫자 자료형
#정수형
print(1)
#실수형
print(3.3)

# // 몫연산자
# % 나머지 연산자
# 거듭제곱을 구하기 **
# 값을 정수로 만들기 int() 함수
# Out:
# 1
# 3.3

# %%
# 변수명은 영문 대소문자, 숫자, 특수문자는 _(언더바만 가능) -> 의미있는 것을 쓰는게 좋다. 첫 문자는 소문자가 좋다.
# 파이썬은 값에 따라서 자료형이 바뀐다. 파이썬의 변수에는 정수뿐만 아니라 문자열도 저장
# data_1 
nX = 100
# .만 찍어도 실수형이 됨
nY = 200.
nTotal = nX + nY
print(nTotal)

# 타입알기
print(type(nX))
# Out:
# 300.0
# <class 'int'>

# %%
#  = 은 오른쪽 갑을 왼쪽에 대입한다는 의미 
#  ==는 비교

# %%
red = 3;
blue = 5;
bucket = red * 5 + blue * 7
print(bucket,"g")
# Out:
# 50 g

# %%
# 1. 문제이해 -> 요구사항 분석
# 2. 변수고민 -> 자료구조
# 3. 구조고민 -> 알고리즘
# 4. 코딩
# 5. 검증(변수를 바꿔보면서 값이 바뀌는지도 확인하면 좋음)

# %%
red_balls = 5
blue_balls = 7

red_ball_weight = 3
blue_ball_weight = 5

total_weight = (red_balls * red_ball_weight) + (blue_balls * blue_ball_weight)

print("통의 총 무게는", total_weight, "g입니다.")
# Out:
# 통의 총 무게는 50 g입니다.

# %%
# 파이썬 변수와 입력 사용해보기

number = input("숫자를 입력하세요:")
print(number)

# 입력 전에 옆에 *이 되는데 실행이 되어야 넘어간다.
# Out:
# 숫자를 입력하세요: 11
# 11

# %%
# 기본으로 받아들이면 문자열로 받아들인다.
inputNum1 = input("숫자를 입력하세요:")
# inputNum1 = int(input("숫자를 입력하세요:"))
inputNum2 = input("숫자를 입력하세요:")
# inputNum2 = int(input("숫자를 입력하세요:"))
print(inputNum1,inputNum2)
print(type(inputNum1),type(inputNum2))
# Out:
# 숫자를 입력하세요: 30
# 숫자를 입력하세요: 5
# 30 5
# <class 'str'> <class 'str'>

# %%
result = (inputNum1 + inputNum2)
# int 처리가 안됨 10 + 20 = 1020으로 됨 
print("결과", result)

result = int(inputNum1) + int(inputNum2)
print("결과", result)
# Out:
# 결과 305
# 결과 35

# %%
# input 함수 
# input 1 2 3
# 여기서는 int(input .. 이런거 안된다. list로 가능
d1,d2,d3 = input("두개의 숫자를 하나씩 입력하세요").split()
print(int(d1) + int(d2) + int(d3))
# Out:
# 두개의 숫자를 하나씩 입력하세요 4 5 8
# 17
