# %% [markdown]
# ![image.png](attachment:41f16b68-13d1-403b-a3de-e3ba21b38df9.png)

# %%
import pandas as pd

df = pd.read_csv("iris.csv", names = ["sepal_length", "sepal_width", "petal_length", "petal_width", "species"])

# %% [markdown]
# ![image.png](attachment:03bcb41a-cbfd-4f40-81b9-991b6ee46c6c.png)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(df, hue = 'species')
plt.show()

# %% [markdown]
# ![image.png](attachment:959f4254-e581-4c65-a5e9-593df32844b0.png)

# %% [markdown]
# ![image.png](attachment:67860596-5043-4c19-929e-2d3a18c33848.png)

# %% [markdown]
# ![image.png](attachment:6499c55b-f4e1-4006-8976-6347d574b151.png)

# %%
df = pd.read_csv('iris.csv',  names = ["sepal_length", "sepal_width", "petal_length", "petal_width", "species"])

dataset = df.values
X = dataset[:, 0:4].astype(float)
Y_obj = dataset[:, 4]

# %% [markdown]
# ![image.png](attachment:e24dcacd-750d-40f2-8563-016548d6270b.png)

# %%
from sklearn.preprocessing import LabelEncoder 

e = LabelEncoder()
e.fit(Y_obj)
Y = e.transform(Y_obj)

# %% [markdown]
# ![image.png](attachment:afecbf8c-c32f-478b-a177-54c59f85504a.png)

# %%
import tensorflow as tf

Y_encoded = tf.keras.utils.to_categorical(Y)

# %% [markdown]
# ![image.png](attachment:5c31fc2d-bed0-414a-939d-b5a0ee6722b7.png)

# %% [markdown]
# ![image.png](attachment:ecce7192-e06c-4eac-a297-eb7884d19ec5.png)

# %% [markdown]
# ![image.png](attachment:54be6274-d7fb-4b30-90a9-31bfe7fe02ac.png)

# %% [markdown]
# ![image.png](attachment:d69ae658-ace4-45b9-ba24-e62734587261.png)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense


model = Sequential()
model.add(Dense(16, input_dim=4, activation='relu'))
model.add(Dense(3, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model.fit(X, Y_encoded, epochs=50, batch_size=1)

print("\n Accuracy: %.4f" % (model.evaluate(X, Y_encoded)[1]))
# Out:
# Epoch 1/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step - accuracy: 0.3067 - loss: 1.0572
# Epoch 2/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 346us/step - accuracy: 0.6733 - loss: 0.7013
# Epoch 3/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 357us/step - accuracy: 0.8267 - loss: 0.5598
# Epoch 4/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 341us/step - accuracy: 0.8600 - loss: 0.4826
# Epoch 5/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step - accuracy: 0.9333 - loss: 0.4245
# Epoch 6/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - accuracy: 0.9067 - loss: 0.3874
# Epoch 7/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - accuracy: 0.9467 - loss: 0.3446
# Epoch 8/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - accuracy: 0.9600 - loss: 0.3260
# Epoch 9/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step - accuracy: 0.9733 - loss: 0.2984
# Epoch 10/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - accuracy: 0.9467 - loss: 0.2794
# Epoch 11/50
# ...

# %% [markdown]
# ![image.png](attachment:ecb303e7-90cf-4b1f-b7b5-e630533fa100.png)

# %% [markdown]
# ![image.png](attachment:e53b9beb-e1ff-4459-a86d-933eef853a3d.png)

# %% [markdown]
# ![image.png](attachment:2d914678-2720-4b8e-a8d7-1618cd165d69.png)

# %% [markdown]
# ![image.png](attachment:ddc26e19-eaf0-4e6b-bffd-b42509af5181.png)

# %% [markdown]
# ![image.png](attachment:e8766bbe-fd95-4a02-96d6-1d969f2eacc8.png)

# %% [markdown]
# ![image.png](attachment:98545743-6387-41c0-8358-a528c50795b6.png)

# %% [markdown]
# ![image.png](attachment:c9ea405e-279d-4798-b771-31b3009e28bf.png)

# %% [markdown]
# ![image.png](attachment:e73bf0b1-5358-4f26-b6c9-eb127107b720.png)

# %% [markdown]
# ![image.png](attachment:a3a8bc0f-31d4-4fe6-b48c-efe41455d55d.png)

# %% [markdown]
# ![image.png](attachment:9b287771-f537-4247-b0c7-caeb043aa5d9.png)

# %% [markdown]
# ![image.png](attachment:ff015c80-871f-4001-91c9-eef916fd469c.png)

# %% [markdown]
# ![image.png](attachment:220a5268-afe2-42b5-976c-e6a59c4dd750.png)
