# %% [markdown]
# ![image.png](attachment:1f504db8-8e3d-46ef-bf09-633d1b7f1d13.png)

# %%
import pandas as pd

df = pd.read_csv(
    'pima-indians-diabetes.csv',
    names=[
        "pregnant", "plasma", "pressure", "thickness",
        "insulin", "BMI", "pedigree", "age", "class"
    ]
)

print(df)
# Out:
#      pregnant  plasma  pressure  thickness  insulin   BMI  pedigree  age  \
# 0           6     148        72         35        0  33.6     0.627   50
# 1           1      85        66         29        0  26.6     0.351   31
# 2           8     183        64          0        0  23.3     0.672   32
# 3           1      89        66         23       94  28.1     0.167   21
# 4           0     137        40         35      168  43.1     2.288   33
# ..        ...     ...       ...        ...      ...   ...       ...  ...
# 763        10     101        76         48      180  32.9     0.171   63
# 764         2     122        70         27        0  36.8     0.340   27
# 765         5     121        72         23      112  26.2     0.245   30
# 766         1     126        60          0        0  30.1     0.349   47
# 767         1      93        70         31        0  30.4     0.315   23
#
#      class
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1
# ..     ...
# ...

# %%
print(df.head(5))
# Out:
#    pregnant  plasma  pressure  thickness  insulin   BMI  pedigree  age  class
# 0         6     148        72         35        0  33.6     0.627   50      1
# 1         1      85        66         29        0  26.6     0.351   31      0
# 2         8     183        64          0        0  23.3     0.672   32      1
# 3         1      89        66         23       94  28.1     0.167   21      0
# 4         0     137        40         35      168  43.1     2.288   33      1

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pregnant   768 non-null    int64
#  1   plasma     768 non-null    int64
#  2   pressure   768 non-null    int64
#  3   thickness  768 non-null    int64
#  4   insulin    768 non-null    int64
#  5   BMI        768 non-null    float64
#  6   pedigree   768 non-null    float64
#  7   age        768 non-null    int64
#  8   class      768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
# None

# %%
print(df.describe())
# Out:
#          pregnant      plasma    pressure   thickness     insulin         BMI  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#          pedigree         age       class
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# ...

# %% [markdown]
# ![image.png](attachment:a71df863-0e7f-4bb1-bbd8-d999dfcf707d.png)

# %%
print(df[['pregnant', 'class']])
# Out:
#      pregnant  class
# 0           6      1
# 1           1      0
# 2           8      1
# 3           1      0
# 4           0      1
# ..        ...    ...
# 763        10      0
# 764         2      0
# 765         5      0
# 766         1      1
# 767         1      0
#
# [768 rows x 2 columns]

# %% [markdown]
# ![image.png](attachment:2e685181-627e-458b-9a77-247a79d53f98.png)

# %%
print(df[['pregnant', 'class']].groupby(['pregnant'], as_index=False).
    mean().sort_values(by='pregnant', ascending=True))
# Out:
#     pregnant     class
# 0          0  0.342342
# 1          1  0.214815
# 2          2  0.184466
# 3          3  0.360000
# 4          4  0.338235
# 5          5  0.368421
# 6          6  0.320000
# 7          7  0.555556
# 8          8  0.578947
# 9          9  0.642857
# 10        10  0.416667
# 11        11  0.636364
# 12        12  0.444444
# 13        13  0.500000
# 14        14  1.000000
# 15        15  1.000000
# 16        17  1.000000

# %% [markdown]
# ![image.png](attachment:1833c692-c99b-4823-a5ca-798aab0d5512.png)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,12))

sns.heatmap(df.corr(), linewidths=0.1, vmax=0.5, cmap=plt.cm.gist_heat,
            linecolor='white', annot=True)
# Out:
# <Axes: >

# %%
# 맨 모서리 값이 0.1~0.2면 상관관계가 있어 보인다 수준이다.

# %% [markdown]
# ![image.png](attachment:b85a267f-76e8-4f81-a945-c3e1e2da9463.png)

# %% [markdown]
# ![image.png](attachment:d7ca664b-abaa-4f8b-9a3e-048b7f131376.png)

# %% [markdown]
# ![image.png](attachment:4b1f1bce-e705-4eaf-8703-6e4d998ae4a0.png)

# %% [markdown]
# ![image.png](attachment:1826bf1e-f990-413a-a1b4-c6b3df5653ca.png)

# %% [markdown]
# ![image.png](attachment:0b42fe49-2ff3-4699-b715-41581fc8b6f7.png)
