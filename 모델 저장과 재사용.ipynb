# %% [markdown]
# ![image.png](attachment:4c78a039-224e-496b-bb61-67b5857b6a44.png)

# %% [markdown]
# ![image.png](attachment:0d51b2bf-6fe3-48c8-9fd3-dbdbab216891.png)

# %% [markdown]
# ![image.png](attachment:7cc3a839-c2c5-4980-b784-93bccc0de091.png)

# %% [markdown]
# ![image.png](attachment:255baebe-e79a-4297-9c2d-ead8f4f939a5.png)

# %% [markdown]
# ![image.png](attachment:feea9b28-07d3-4ce0-ace4-2ef1e07f5f7d.png)

# %% [markdown]
# ![image.png](attachment:36f104e8-0b65-4a42-bc56-282bd6449ebb.png)

# %% [markdown]
# ![image.png](attachment:d38eb93b-1d87-4e42-89fc-25eefdbe2cc6.png)

# %% [markdown]
# ![image.png](attachment:8868bc3b-3f95-4e10-ac9e-08bd5662cd24.png)

# %% [markdown]
# ![image.png](attachment:60c1c37a-5d93-4896-b4d9-55ca8dc3e05c.png)

# %%
# 1. 데이터 셋 생성 -> 전처리 -> 학습 -> 모델 생성 -> 모델 저장
# 2. 선형회귀는 linear-mse, 단항 분류는 sigmoid-binary-crossentropy, 다항 분류는 softmax-categorical_crossentropy
# 3. loss - 실제값과 예측값의 차이, optimizer - 가중치 업데이트 Adam, SDG, accuracy - 정확도
# 4 epochs - 전체 데이터를 몇 번 반복 학습할지 숫자를 정의, batch_size - 한번에 학습할 데이터 개수

# %% [markdown]
# ![image.png](attachment:224c6189-d9b2-4a45-8234-7a4e948a785b.png)
