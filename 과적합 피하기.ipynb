# %% [markdown]
# ![image.png](attachment:5f31db14-fced-4fb7-854b-1e9a0f715d31.png)

# %% [markdown]
# ![image.png](attachment:1080d9d6-c910-490d-8e7f-4a4db0114509.png)

# %%
import pandas as pd 

df = pd.read_csv('sonar.csv', header=None)
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       208 non-null    float64
#  1   1       208 non-null    float64
#  2   2       208 non-null    float64
#  3   3       208 non-null    float64
#  4   4       208 non-null    float64
#  5   5       208 non-null    float64
#  6   6       208 non-null    float64
#  7   7       208 non-null    float64
#  8   8       208 non-null    float64
#  9   9       208 non-null    float64
#  10  10      208 non-null    float64
#  11  11      208 non-null    float64
#  12  12      208 non-null    float64
#  13  13      208 non-null    float64
#  14  14      208 non-null    float64
#  15  15      208 non-null    float64
#  16  16      208 non-null    float64
#  17  17      208 non-null    float64
#  18  18      208 non-null    float64
#  19  19      208 non-null    float64
#  20  20      208 non-null    float64
# ...

# %% [markdown]
# ![image.png](attachment:515cee3e-c2d7-449c-a7e4-89368c0999ed.png)

# %% [markdown]
# ![image.png](attachment:2d29adbe-eb9a-4f34-9ec3-97f950f05164.png)

# %% [markdown]
# ![image.png](attachment:803ad447-1f74-4a20-97b1-0dc57f71f4bf.png)

# %% [markdown]
# ![image.png](attachment:9800459a-7023-4f1e-aee9-58f1bf5b04d6.png)

# %% [markdown]
# ![image.png](attachment:690fc73e-5f88-4986-b69a-246c13a7fd1b.png)

# %% [markdown]
# ![image.png](attachment:54d81cf4-4420-487c-93eb-187d98d8d282.png)

# %%
# 너무 많은 레이어나 데이터가 있을 때
# 학습을 너무 많이 했을 때

# %% [markdown]
# ![image.png](attachment:6dcb034a-d4e7-48a3-b73e-a09825812757.png)

# %% [markdown]
# ![image.png](attachment:673d8407-1d71-426c-a735-dbfcc561570e.png)

# %%
# 일정 부분은 학습에 사용하고, 일정 부분은 검증에 사용 (85(이떄 또 8대 2)대 15 비율정도)

# Train set -> 학습에 사용하는 데이터 셋
# val set(Validation set) -> 매 epoch 마다 학습을 하고 검증을 할 때 사용하는 데이터 셋
# Test set -> 학습에 관여하지 않고, 결과 비교에 사용한다. 

# 근데 그냥 Train set과  val set으로만 해도 가능하다 어차피 val set이 매번 참여해서 검증하기 때문이다.

# %% [markdown]
# ![image.png](attachment:efe64e07-6e60-46c1-ae96-a06673e97ece.png)

# %% [markdown]
# ![image.png](attachment:d1865076-2956-499d-99f2-b52113882a37.png)

# %% [markdown]
# ![image.png](attachment:ed4a8181-740d-4d6b-b3a6-e04e02e23fbd.png)

# %% [markdown]
# ![image.png](attachment:2d944501-b18a-47c5-b31a-03a8616a669b.png)

# %% [markdown]
# ![image.png](attachment:bc526d24-4520-4fa8-bc67-044e18bc16d1.png)

# %% [markdown]
# ![image.png](attachment:a987be59-394f-4e21-b0aa-d39ef571fe12.png)

# %% [markdown]
# ![image.png](attachment:3effed13-8807-4b67-9fac-d7b0510ea1c1.png)

# %% [markdown]
# ![image.png](attachment:c40afd1e-4003-4c7a-84dd-50abb936ece4.png)

# %%
# 중간 저장되는 값은 파라미터이다 (w ,b ) 가중치랑 바이어스

# %% [markdown]
# ![image.png](attachment:6caca6f7-9311-42a0-a9d6-923b6c173330.png)

# %% [markdown]
# ![image.png](attachment:89acbe6d-eb6a-462f-9f19-0110d369c24f.png)

# %% [markdown]
# ![image.png](attachment:e29a606e-0c81-4492-af8c-45ea504a06ae.png)

# %% [markdown]
# ![image.png](attachment:1b7bbd01-9809-4e80-b9f4-da8f31d858e9.png)

# %% [markdown]
# ![image.png](attachment:adee732c-dd59-4283-a4f9-d9ccc6177470.png)
