# %% [markdown]
# ![image.png](attachment:240cd17e-8bc3-4638-b047-cf4345266027.png)

# %% [markdown]
# ![image.png](attachment:238cefd6-d019-4834-9c95-eeeaf9dd3cee.png)

# %% [markdown]
# ![image.png](attachment:e5320c1d-bf34-4d7d-9382-272de645f8f3.png)

# %% [markdown]
# ![image.png](attachment:177dfbf9-2fa3-46b8-8d91-6132b03db897.png)

# %% [markdown]
# ![image.png](attachment:0b305f36-2fba-43a5-b62c-bd6094b2dbe9.png)

# %% [markdown]
# ![image.png](attachment:718e5022-a29f-4c9c-9d61-be41ddcb95fe.png)

# %% [markdown]
# ![image.png](attachment:01411574-7dd0-49ee-aec9-2954187f164d.png)

# %% [markdown]
# ![image.png](attachment:d51acb03-de44-46de-9060-31c7287d88d9.png)

# %% [markdown]
# ![image.png](attachment:68a81605-ce17-41af-b2c9-282ade4f71a1.png)

# %%
import numpy as np

# 데이터 정의 (입력 데이터와 출력 데이터)
data_x = np.array([10, 20, 30, 40])
data_y = np.array([21, 49, 68, 80])

# 평균값 계산
mean_x = np.mean(data_x)
mean_y = np.mean(data_y)

# 기울기 계산 
numerator = np.sum((data_x - mean_x) * (data_y - mean_y))
denominator = np.sum((data_x - mean_x) ** 2)
slope = numerator / denominator

# 절편 계산
intercept = mean_y - slope * mean_x

# 결과 출력
print("기울기:", slope)
print("절편:", intercept)
# Out:
# 기울기: 1.96
# 절편: 5.5

# %% [markdown]
# ![image.png](attachment:94292e4d-4730-4f7a-bd19-b84f71c302d2.png)

# %% [markdown]
# ![image.png](attachment:b135a448-cfab-4ae1-9969-6602b30222a6.png)

# %%
# 아무 기울기 선을 막 긋다가 그 선이 데이터를 가장 잘 표현할 떄 멈추라
# 그럼 이때 "잘 표현한다는 것이 무엇인가?"

# %% [markdown]
# ![image.png](attachment:4c64fd62-ad97-40d3-8dcc-7e6ee784fc72.png)

# %% [markdown]
# ![image.png](attachment:f857cd7f-eb8d-46a6-819f-3613e668c558.png)

# %%
# 데이터를 가장 잘 표현한다. -> 예측값과 실체값의 오차를 줄인다
# 오차(실체값과 예측값의 차이)를 줄이기 위해 파라미터 값(y = ax + b)을 변경하는 것 -> 이것이 딥러닝 모델링이다.
# 오차가 클수록 a와 b를 찾아가는데에서 편하다. -> 오차를 크게하는 법(제곱 해보기) loss = 'mse'

# %% [markdown]
# ![image.png](attachment:8854c7d4-11ee-431a-a04c-b9c3e8572659.png)

# %%
# 경사하강법에서 미분을 하려면 오차가 커야지 잘 진행된다.

# %% [markdown]
# ![image.png](attachment:63c5e019-7f03-441f-a493-3336195ce414.png)

# %% [markdown]
# ![image.png](attachment:c2c10e65-e837-48a9-bbf1-84e41d189e66.png)

# %% [markdown]
# ![image.png](attachment:6dc81ee8-28d3-44a7-a86e-eb7260cfe864.png)

# %% [markdown]
# ![image.png](attachment:a115575f-6b48-4ef0-9298-102e03890961.png)

# %%
# 선이 최고의 위치를 찾아가는 방법을 알아가는 과정을 배운다.
# loss(오차)가 작은 값으로 간다.
